# %%
import sys
import pandas as pd

### IMPORTANT ###
# Make sure you are correctly appending the path
# Otherwise the imports will not work!
sys.path.append("..")
from src.movielens_data.movielens import movielens
from src.movielens_data.movielens import cluster

# %%
from lenskit.datasets import ML100K
dataset = ML100K('/Users/pvs262/Library/Python/3.8/lib/python/site-packages/lenskit/data/ml-100k')
ratings = dataset.ratings
movies = dataset.movies

# %%
ratings.head()
# Out:
#    user  item  rating  timestamp
# 0   196   242     3.0  881250949
# 1   186   302     3.0  891717742
# 2    22   377     1.0  878887116
# 3   244    51     2.0  880606923
# 4   166   346     1.0  886397596

# %%
movies
# Out:
#                                           title      release  vidrelease  \
# item
# 1                              Toy Story (1995)  01-Jan-1995         NaN
# 2                              GoldenEye (1995)  01-Jan-1995         NaN
# 3                             Four Rooms (1995)  01-Jan-1995         NaN
# 4                             Get Shorty (1995)  01-Jan-1995         NaN
# 5                                Copycat (1995)  01-Jan-1995         NaN
# ...                                         ...          ...         ...
# 1678                          Mat' i syn (1997)  06-Feb-1998         NaN
# 1679                           B. Monkey (1998)  06-Feb-1998         NaN
# 1680                       Sliding Doors (1998)  01-Jan-1998         NaN
# 1681                        You So Crazy (1994)  01-Jan-1994         NaN
# 1682  Scream of Stone (Schrei aus Stein) (1991)  08-Mar-1996         NaN
#
#                                                    imdb  unknown  Action  \
# item
# 1     http://us.imdb.com/M/title-exact?Toy%20Story%2...        0       0
# 2     http://us.imdb.com/M/title-exact?GoldenEye%20(...        0       1
# 3     http://us.imdb.com/M/title-exact?Four%20Rooms%...        0       0
# 4     http://us.imdb.com/M/title-exact?Get%20Shorty%...        0       1
# 5     http://us.imdb.com/M/title-exact?Copycat%20(1995)        0       0
# ...                                                 ...      ...     ...
# 1678  http://us.imdb.com/M/title-exact?Mat%27+i+syn+...        0       0
# 1679  http://us.imdb.com/M/title-exact?B%2E+Monkey+(...        0       0
# 1680      http://us.imdb.com/Title?Sliding+Doors+(1998)        0       0
# 1681  http://us.imdb.com/M/title-exact?You%20So%20Cr...        0       0
# 1682  http://us.imdb.com/M/title-exact?Schrei%20aus%...        0       0
#
#       Adventure  Animation  Children's  Comedy  ...  Fantasy  Film-Noir  \
# item                                            ...
# 1             0          1           1       1  ...        0          0
# 2             1          0           0       0  ...        0          0
# 3             0          0           0       0  ...        0          0
# 4             0          0           0       1  ...        0          0
# 5             0          0           0       0  ...        0          0
# ...         ...        ...         ...     ...  ...      ...        ...
# 1678          0          0           0       0  ...        0          0
# 1679          0          0           0       0  ...        0          0
# 1680          0          0           0       0  ...        0          0
# 1681          0          0           0       1  ...        0          0
# 1682          0          0           0       0  ...        0          0
#
#       Horror  Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western
# item
# 1          0        0        0        0       0         0    0        0
# 2          0        0        0        0       0         1    0        0
# 3          0        0        0        0       0         1    0        0
# 4          0        0        0        0       0         0    0        0
# 5          0        0        0        0       0         1    0        0
# ...      ...      ...      ...      ...     ...       ...  ...      ...
# 1678       0        0        0        0       0         0    0        0
# 1679       0        0        0        1       0         1    0        0
# 1680       0        0        0        1       0         0    0        0
# 1681       0        0        0        0       0         0    0        0
# 1682       0        0        0        0       0         0    0        0
#
# [1682 rows x 23 columns]

# %%
# Instantiate movielens object
data = movielens(movies=movies, ratings=ratings)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genres'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-c972d6ec259b> in <module>
#       1 # Instantiate movielens object
# ----> 2 data = movielens(movies=movies, ratings=ratings)
#
# ~/Documents/rec-sys-dynamics/code/src/movielens_data/movielens.py in __init__(self, movies, ratings)
#      31
#      32         # Identify genres in dataset
# ---> 33         self.get_dummy_genres()
#      34
#      35         # Enable logging
#
# ~/Documents/rec-sys-dynamics/code/src/movielens_data/movielens.py in get_dummy_genres(self)
#      89     # Function to split movie genres into dummy variables
#      90     def get_dummy_genres(self):
# ---> 91         genres_list = self.movies['genres'].str.split(pat='|') # convert string to list of string
#      92         self.movies2 = pd.concat([self.movies.drop(['genres','title'],axis=1), genres_list.str.join('|').str.get_dummies()], axis=1) # concatenate dummy variables df of genres
#      93         self.genres = self.movies2.columns.tolist()[1:]
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'genres'

# %%
# User-Item Interaction Matrix
dataUI = data.UserItem()    
dataUI

# %%
# Instantiate clustering object
ML_clusters = cluster(dataUI)

# %%
# %%time
ML_clusters.SVD(3)

# %%
# %%time
ML_clusters.addRating(611,2,0)

# %%
ML_clusters.SVD(3)

# %%
### IMPORTANT: Make sure you train the model/clusters before plotting them. 

# perform GMM clustering to get cluster values and cluster probabilities
# df = 'pred' for cluster predictions, 'proba' for clusters + probabilities, 'full' for latent values+clusters+probas
gmm_cluster_probas = ML_clusters.gmm(n=3,covariance_type="full",df='proba')

# perform KMeans cliustering to get cluster values (Note: cannot provide cluster probabilities)
km_clusters = ML_clusters.kmeans(3)

# %%
# plot data and clusters (True for colour-coded clusters, if False it will just plot latent features in monotone)
# These functions currently only work in JupyterNotebook.                            
ML_clusters.plotScatter(True, 'kmeans')
ML_clusters.plotScatter(True, 'gmm')

# %%
dataUI.head()

# %%
dataUI[193570] = 0

# %%
dataUI

# %%
import numpy as np
dataUI.loc[len(dataUI)+1] = np.zeros(len(dataUI.columns))

# %%
dataUI
